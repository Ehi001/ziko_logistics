
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting requests>=2.21.0 (from azure-core>=1.30.0->azure-storage-blob)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: six>=1.11.0 in c:\users\oaikhena\appdata\roaming\python\python311\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.17.0)
# Collecting cffi>=1.12 (from cryptography>=2.1.4->azure-storage-blob)
#   Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl.metadata (1.6 kB)
# Collecting pycparser (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Collecting charset-normalizer<4,>=2 (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob)
#   Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Downloading azure_storage_blob-12.25.0-py3-none-any.whl (406 kB)
#    ---------------------------------------- 0.0/406.9 kB ? eta -:--:--
#    ------- -------------------------------- 71.7/406.9 kB 2.0 MB/s eta 0:00:01
#    ------------------------------ --------- 307.2/406.9 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 406.9/406.9 kB 4.3 MB/s eta 0:00:00
# Downloading azure_core-1.32.0-py3-none-any.whl (198 kB)
#    ---------------------------------------- 0.0/198.9 kB ? eta -:--:--
#    --------------------------------------- 198.9/198.9 kB 12.6 MB/s eta 0:00:00
# Downloading cryptography-44.0.2-cp39-abi3-win_amd64.whl (3.2 MB)
#    ---------------------------------------- 0.0/3.2 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.2 MB 16.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 0.9/3.2 MB 11.6 MB/s eta 0:00:01
#    --------------- ------------------------ 1.3/3.2 MB 10.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.9/3.2 MB 10.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.3/3.2 MB 10.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 2.9/3.2 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  3.2/3.2 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.2/3.2 MB 9.8 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading cffi-1.17.1-cp311-cp311-win_amd64.whl (181 kB)
#    ---------------------------------------- 0.0/181.4 kB ? eta -:--:--
#    ---------------------------------------- 181.4/181.4 kB 5.5 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ---------------------------------------- 64.9/64.9 kB 3.4 MB/s eta 0:00:00
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
#    ---------------------------------------- 0.0/166.4 kB ? eta -:--:--
#    ---------------------------------------- 166.4/166.4 kB 4.9 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp311-cp311-win_amd64.whl (102 kB)
#    ---------------------------------------- 0.0/102.4 kB ? eta -:--:--
#    ---------------------------------------- 102.4/102.4 kB 6.1 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.4 kB ? eta -:--:--
#    ---------------------------------------- 70.4/70.4 kB ? eta 0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ---------------------------------------- 0.0/128.4 kB ? eta -:--:--
#    ---------------------------------------- 128.4/128.4 kB 7.4 MB/s eta 0:00:00
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ---------------------------------------- 0.0/117.6 kB ? eta -:--:--
#    ---------------------------------------- 117.6/117.6 kB ? eta 0:00:00
# Installing collected packages: urllib3, pycparser, isodate, idna, charset-normalizer, certifi, requests, cffi, cryptography, azure-core, azure-storage-blob
# Successfully installed azure-core-1.32.0 azure-storage-blob-12.25.0 certifi-2025.1.31 cffi-1.17.1 charset-normalizer-3.4.1 cryptography-44.0.2 idna-3.10 isodate-0.7.2 pycparser-2.22 requests-2.32.3 urllib3-2.3.0
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install python-dotenv
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Installing necessary dependencies

# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\oaikhena\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\oaikhena\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\oaikhena\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\oaikhena\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\oaikhena\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\oaikhena\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Import necessary libraries

import pandas as pd
import os
import io
from azure.storage.blob import BlobServiceClient, BlobClient
from dotenv import load_dotenv

# %%
#Exctract data from csv

ziko_df = pd.read_csv(r"ziko_logistics_data.csv")

# %%
ziko_df.head()
# Out:
#    Transaction_ID                           Date  Customer_ID  Product_ID  \
# 0             200  2020-01-01 20:32:25.945945945         1086         536
# 1             321  2020-01-02 06:55:08.108108108         1078         523
# 2             989  2020-01-06 08:12:58.378378378         1077         535
# 3             682  2020-01-07 22:03:14.594594594         1027         546
# 4             484  2020-01-07 07:08:06.486486486         1052         556
#
#    Quantity  Unit_Price   Total_Cost  Discount_Rate Sales_Channel  \
# 0         3  120.436821  8265.374549           0.20        Online
# 1         6  475.724994  4047.850479            NaN      Reseller
# 2         3  146.400556          NaN           0.05        Direct
# 3         6   19.373194  8194.281993            NaN      Reseller
# 4         8  193.221313  8331.329249           0.20        Direct
#
#   Order_Priority  ... Return_Reason   Payment_Type Taxable Region  Country  \
# 0           High  ...    Wrong Item  Wire Transfer   False   West   Canada
# 1       Critical  ...       Damaged         PayPal    True  South   Mexico
# 2       Critical  ...       Damaged         PayPal    True   West   Canada
# 3         Medium  ...    Wrong Item           Cash    True  South   Canada
# 4            Low  ...          Late           Cash   False  South   Mexico
#
#   Customer_Name   Customer_Phone               Customer_Email  \
# 0  Customer 200  +1-652-572-9306  customer.200.78@example.com
# 1  Customer 321  +1-311-186-5760   customer.321.13@sample.com
# 2  Customer 989  +1-922-606-9032  customer.989.99@example.com
# 3  Customer 682  +1-237-853-5808     customer.682.66@demo.com
# 4  Customer 484  +1-986-360-9109    customer.484.3@sample.com
#
#                Customer_Address Product_List_Title
# 0   275 Second St, Phoenix, USA         Product 53
# 1   478 Third St, New York, USA         Product 33
# 2   843 Second St, Phoenix, USA          Product 6
# 3     153 Main St, Phoenix, USA         Product 68
# 4  264 Second St, New York, USA         Product 89
#
# [5 rows x 25 columns]

# %%
ziko_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Transaction_ID         1005 non-null   int64
#  1   Date                   1005 non-null   object
#  2   Customer_ID            1005 non-null   int64
#  3   Product_ID             1005 non-null   int64
#  4   Quantity               1005 non-null   int64
#  5   Unit_Price             904 non-null    float64
#  6   Total_Cost             905 non-null    float64
#  7   Discount_Rate          714 non-null    float64
#  8   Sales_Channel          1005 non-null   object
#  9   Order_Priority         1005 non-null   object
#  10  Warehouse_Code         1005 non-null   object
#  11  Ship_Mode              1005 non-null   object
#  12  Delivery_Status        1005 non-null   object
#  13  Customer_Satisfaction  1005 non-null   object
#  14  Item_Returned          1005 non-null   bool
#  15  Return_Reason          904 non-null    object
#  16  Payment_Type           1005 non-null   object
#  17  Taxable                1005 non-null   bool
#  18  Region                 1005 non-null   object
#  19  Country                1005 non-null   object
#  20  Customer_Name          1005 non-null   object
#  21  Customer_Phone         1005 non-null   object
#  22  Customer_Email         1005 non-null   object
#  23  Customer_Address       1005 non-null   object
#  24  Product_List_Title     1005 non-null   object
# dtypes: bool(2), float64(3), int64(4), object(16)
# memory usage: 182.7+ KB

# %%
ziko_df.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_ID', 'Product_ID', 'Quantity',
#        'Unit_Price', 'Total_Cost', 'Discount_Rate', 'Sales_Channel',
#        'Order_Priority', 'Warehouse_Code', 'Ship_Mode', 'Delivery_Status',
#        'Customer_Satisfaction', 'Item_Returned', 'Return_Reason',
#        'Payment_Type', 'Taxable', 'Region', 'Country', 'Customer_Name',
#        'Customer_Phone', 'Customer_Email', 'Customer_Address',
#        'Product_List_Title'],
#       dtype='object')

# %%
# Data cleaning and transformation

ziko_df = ziko_df.fillna({
    'Unit_Price' : ziko_df['Unit_Price'].mean(),
    'Total_Cost' : ziko_df['Total_Cost'].mean(),
    'Discount_Rate' : 0.0,
    'Return_Reason' : 'Unknown'
})

# %%
ziko_df['Date'] = pd.to_datetime(ziko_df['Date'])

# %%
ziko_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Transaction_ID         1005 non-null   int64
#  1   Date                   1005 non-null   datetime64[ns]
#  2   Customer_ID            1005 non-null   int64
#  3   Product_ID             1005 non-null   int64
#  4   Quantity               1005 non-null   int64
#  5   Unit_Price             1005 non-null   float64
#  6   Total_Cost             1005 non-null   float64
#  7   Discount_Rate          1005 non-null   float64
#  8   Sales_Channel          1005 non-null   object
#  9   Order_Priority         1005 non-null   object
#  10  Warehouse_Code         1005 non-null   object
#  11  Ship_Mode              1005 non-null   object
#  12  Delivery_Status        1005 non-null   object
#  13  Customer_Satisfaction  1005 non-null   object
#  14  Item_Returned          1005 non-null   bool
#  15  Return_Reason          1005 non-null   object
#  16  Payment_Type           1005 non-null   object
#  17  Taxable                1005 non-null   bool
#  18  Region                 1005 non-null   object
#  19  Country                1005 non-null   object
#  20  Customer_Name          1005 non-null   object
#  21  Customer_Phone         1005 non-null   object
#  22  Customer_Email         1005 non-null   object
#  23  Customer_Address       1005 non-null   object
#  24  Product_List_Title     1005 non-null   object
# dtypes: bool(2), datetime64[ns](1), float64(3), int64(4), object(15)
# memory usage: 182.7+ KB

# %% [markdown]
# ### Create the different tables in the Model

# %%
# Customer table
customer = ziko_df[['Customer_ID', 'Customer_Name', 'Customer_Phone', 'Customer_Email', 'Customer_Address']].copy().drop_duplicates().reset_index(drop = True)

customer.head()
# Out:
#    Customer_ID Customer_Name   Customer_Phone               Customer_Email  \
# 0         1086  Customer 200  +1-652-572-9306  customer.200.78@example.com
# 1         1078  Customer 321  +1-311-186-5760   customer.321.13@sample.com
# 2         1077  Customer 989  +1-922-606-9032  customer.989.99@example.com
# 3         1027  Customer 682  +1-237-853-5808     customer.682.66@demo.com
# 4         1052  Customer 484  +1-986-360-9109    customer.484.3@sample.com
#
#                Customer_Address
# 0   275 Second St, Phoenix, USA
# 1   478 Third St, New York, USA
# 2   843 Second St, Phoenix, USA
# 3     153 Main St, Phoenix, USA
# 4  264 Second St, New York, USA

# %%
customer.shape
# Out:
# (1000, 5)

# %%
# Products table
product = ziko_df[['Product_ID', 'Product_List_Title', 'Unit_Price', 'Discount_Rate', 'Warehouse_Code',]].copy().drop_duplicates().reset_index(drop = True)

# %%
product.head()
# Out:
#    Product_ID Product_List_Title  Unit_Price  Discount_Rate Warehouse_Code
# 0         536         Product 53  120.436821           0.20           WH-3
# 1         523         Product 33  475.724994           0.00           WH-1
# 2         535          Product 6  146.400556           0.05           WH-1
# 3         546         Product 68   19.373194           0.00           WH-1
# 4         556         Product 89  193.221313           0.20           WH-2

# %%
product.shape
# Out:
# (1000, 5)

# %%
# Transaction fact table
transaction_fact = ziko_df.merge(customer, on = ['Customer_ID', 'Customer_Name','Customer_Phone', 'Customer_Email', 'Customer_Address'], how = 'left')\
                          .merge(product, on = ['Product_ID', 'Product_List_Title', 'Unit_Price', 'Discount_Rate', 'Warehouse_Code',], how = 'left')\
                          [['Transaction_ID', 'Date', 'Customer_ID', 'Product_ID', 'Quantity', 'Total_Cost',  'Sales_Channel','Order_Priority', \
                            'Ship_Mode', 'Delivery_Status','Customer_Satisfaction', 'Item_Returned', 'Return_Reason','Payment_Type', 'Taxable', 'Region', 'Country']]

# %%
transaction_fact.shape
# Out:
# (1005, 17)

# %%
transaction_fact.drop_duplicates().reset_index(drop = True)
# Out:
#      Transaction_ID                          Date  Customer_ID  Product_ID  \
# 0               200 2020-01-01 20:32:25.945945945         1086         536
# 1               321 2020-01-02 06:55:08.108108108         1078         523
# 2               989 2020-01-06 08:12:58.378378378         1077         535
# 3               682 2020-01-07 22:03:14.594594594         1027         546
# 4               484 2020-01-07 07:08:06.486486486         1052         556
# ..              ...                           ...          ...         ...
# 995             250 2020-01-05 02:22:42.162162162         1095         533
# 996             412 2020-01-07 11:27:34.054054054         1008         542
# 997             816 2020-01-06 02:48:38.918918918         1060         511
# 998             702 2020-01-09 08:38:55.135135135         1054         504
# 999               4 2020-01-03 10:22:42.162162162         1018         545
#
#      Quantity   Total_Cost Sales_Channel Order_Priority  Ship_Mode  \
# 0           3  8265.374549        Online           High      2-Day
# 1           6  4047.850479      Reseller       Critical  Overnight
# 2           3  5096.553818        Direct       Critical  Overnight
# 3           6  8194.281993      Reseller         Medium    Express
# 4           8  8331.329249        Direct            Low      2-Day
# ..        ...          ...           ...            ...        ...
# 995         5  1138.724711      Reseller         Medium    Express
# 996         9  1786.865600        Online         Medium      2-Day
# 997         6  6443.682500       Partner         Medium      2-Day
# 998         6  4814.744796        Online         Medium    Regular
# 999         2  1971.790456        Direct            Low      2-Day
#
#     Delivery_Status Customer_Satisfaction  Item_Returned  Return_Reason  \
# 0         Cancelled               Neutral          False     Wrong Item
# 1         Backorder             Satisfied           True        Damaged
# 2           Pending           Unsatisfied           True        Damaged
# 3           Pending           Unsatisfied          False     Wrong Item
# 4         Delivered             Satisfied           True           Late
# ..              ...                   ...            ...            ...
# 995       Delivered           Unsatisfied           True        Damaged
# 996       Cancelled               Neutral           True  Not Specified
# 997       Cancelled           Unsatisfied           True  Not Specified
# 998       Cancelled             Satisfied          False        Damaged
# 999       Backorder           Unsatisfied           True  Not Specified
#
#       Payment_Type  Taxable Region Country
# 0    Wire Transfer    False   West  Canada
# 1           PayPal     True  South  Mexico
# 2           PayPal     True   West  Canada
# 3             Cash     True  South  Canada
# 4             Cash    False  South  Mexico
# ..             ...      ...    ...     ...
# 995    Credit Card     True  South  Canada
# 996           Cash     True  South     USA
# 997           Cash    False   West  Mexico
# 998           Cash     True   West  Canada
# 999           Cash     True   East  Canada
#
# [1000 rows x 17 columns]

# %%
transaction_fact['Date'] = transaction_fact['Date'].astype('datetime64[us]')

# %%
# temporary loading

customer.to_csv(r'dataset/customer.csv', index = False)
product.to_csv(r'dataset/product.csv', index = False)
transaction_fact.to_csv(r'dataset/transaction_fact', index = False)

# %%
# Data Loading to Azure Cloud

# Azure Blob Connection

load_dotenv()

connect_str = os.getenv('CONNECT_STR')
blob_service_client = BlobServiceClient.from_connection_string(connect_str)

container_name = os.getenv('CONTAINER_NAME')
container_client = blob_service_client.get_container_client(container_name)

# %%
# Create a function that will load the data into Azure blob storage as parquet file

def upload_df_to_blob_as_parquet(df, container_client, blob_name):
    buffer = io.BytesIO()
    df.to_parquet(buffer, index = False)
    buffer.seek(0)
    blob_client = container_client.get_blob_client(blob_name)
    blob_client.upload_blob(buffer, blob_type = "BlockBlob", overwrite = True)
    print(f'{blob_name} uploaded to Blob storage successfully')

# %%
upload_df_to_blob_as_parquet(customer, container_client, 'rawdata/customer.parquet')
upload_df_to_blob_as_parquet(product, container_client, 'rawdata/product.parquet')
upload_df_to_blob_as_parquet(transaction_fact, container_client, 'rawdata/transaction_fact.parquet')
# Out:
# rawdata/customer.parquet uploaded to Blob storage successfully
# rawdata/product.parquet uploaded to Blob storage successfully
# rawdata/transaction_fact.parquet uploaded to Blob storage successfully
